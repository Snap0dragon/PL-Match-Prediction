# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/822bd0ba/Liverpool-Stats',
#  '/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  '/en/squads/fd962109/Fulham-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats',
#  '/en/squads/e297cd13/Luton-Town-Stats',
#  '/en/squads/4ba7cbea/Bournemouth-Stats',
#  '/en/squads/943e8050/Burnley-Stats',
#  '/en/squads/1df6b87e/Sheffield-United-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/e297cd13/Luton-Town-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/943e8050/Burnley-Stats',
#  'https://fbref.com/en/squads/1df6b87e/Sheffield-United-Stats']

# %%
import pandas as pd
team_url = team_urls[0]

# %%
data = requests.get(team_url)
matches = pd.read_html(data.text, match='Scores & Fixtures')

# %%
matches[0]
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1   2023-08-11  20:00    Premier League          Matchweek 1  Fri     Away
# 2   2023-08-16  22:00         Super Cup       UEFA Super Cup  Wed     Home
# 3   2023-08-19  20:00    Premier League          Matchweek 2  Sat     Home
# 4   2023-08-27  14:00    Premier League          Matchweek 3  Sun     Away
# 5   2023-09-02  15:00    Premier League          Matchweek 4  Sat     Home
# 6   2023-09-16  15:00    Premier League          Matchweek 5  Sat     Away
# 7   2023-09-19  20:00      Champions Lg          Group stage  Tue     Home
# 8   2023-09-23  15:00    Premier League          Matchweek 6  Sat     Home
# 9   2023-09-27  20:00           EFL Cup          Third round  Wed     Away
# 10  2023-09-30  15:00    Premier League          Matchweek 7  Sat     Away
# 11  2023-10-04  21:00      Champions Lg          Group stage  Wed     Away
# 12  2023-10-08  16:30    Premier League          Matchweek 8  Sun     Away
# 13  2023-10-21  15:00    Premier League          Matchweek 9  Sat     Home
# 14  2023-10-25  21:00      Champions Lg          Group stage  Wed     Away
# 15  2023-10-29  15:30    Premier League         Matchweek 10  Sun     Away
# 16  2023-11-04  15:00    Premier League         Matchweek 11  Sat     Home
# 17  2023-11-07  20:00      Champions Lg          Group stage  Tue     Home
# 18  2023-11-12  16:30    Premier League         Matchweek 12  Sun     Away
# 19  2023-11-25  12:30    Premier League         Matchweek 13  Sat     Home
# 20  2023-11-28  20:00      Champions Lg          Group stage  Tue     Home
# 21  2023-12-03  16:30    Premier League         Matchweek 14  Sun     Home
# 22  2023-12-06  20:15    Premier League         Matchweek 15  Wed     Away
# 23  2023-12-10  14:00    Premier League         Matchweek 16  Sun     Away
# 24  2023-12-13  18:45      Champions Lg          Group stage  Wed     Away
# 25  2023-12-16  15:00    Premier League         Matchweek 17  Sat     Home
# 26  2023-12-23    NaN    Premier League         Matchweek 18  Sat     Home
# 27  2023-12-27  20:15    Premier League         Matchweek 19  Wed     Away
# 28  2023-12-30  15:00    Premier League         Matchweek 20  Sat     Home
# 29  2024-01-13  17:30    Premier League         Matchweek 21  Sat     Away
# 30  2024-01-31  20:00    Premier League         Matchweek 22  Wed     Home
# 31  2024-02-03    NaN    Premier League         Matchweek 23  Sat     Away
# 32  2024-02-10    NaN    Premier League         Matchweek 24  Sat     Home
# 33  2024-02-17    NaN    Premier League         Matchweek 25  Sat     Home
# 34  2024-02-24    NaN    Premier League         Matchweek 26  Sat     Away
# 35  2024-03-02    NaN    Premier League         Matchweek 27  Sat     Home
# 36  2024-03-09    NaN    Premier League         Matchweek 28  Sat     Away
# 37  2024-03-16    NaN    Premier League         Matchweek 29  Sat     Away
# 38  2024-03-30    NaN    Premier League         Matchweek 30  Sat     Home
# 39  2024-04-03    NaN    Premier League         Matchweek 31  Wed     Home
# 40  2024-04-06    NaN    Premier League         Matchweek 32  Sat     Away
# 41  2024-04-13    NaN    Premier League         Matchweek 33  Sat     Home
# 42  2024-04-20    NaN    Premier League         Matchweek 34  Sat     Away
# 43  2024-04-27    NaN    Premier League         Matchweek 35  Sat     Away
# 44  2024-05-04    NaN    Premier League         Matchweek 36  Sat     Home
# 45  2024-05-11    NaN    Premier League         Matchweek 37  Sat     Away
# 46  2024-05-19    NaN    Premier League         Matchweek 38  Sun     Home
#
#    Result     GF     GA         Opponent   xG  xGA  Poss  Attendance  \
# 0       D  1 (1)  1 (4)          Arsenal  NaN  NaN  55.0     81145.0
# 1       W      3      0          Burnley  1.9  0.3  65.0     21572.0
# 2       D  1 (5)  1 (4)       es Sevilla  NaN  NaN  74.0         NaN
# 3       W      1      0    Newcastle Utd  1.0  0.3  59.0         NaN
# 4       W      2      1    Sheffield Utd  3.5  0.7  79.0     31336.0
# 5       W      5      1           Fulham  2.2  1.4  68.0     52899.0
# 6       W      3      1         West Ham  3.6  0.9  68.0     62475.0
# 7       W      3      1      rs Red Star  4.1  0.8  76.0     50204.0
# 8       W      2      0  Nott'ham Forest  1.3  1.0  57.0     53413.0
# 9       L      0      1    Newcastle Utd  NaN  NaN  67.0     51692.0
# 10      L      1      2           Wolves  0.9  0.4  68.0     31415.0
# 11      W      3      1    de RB Leipzig  2.2  0.5  68.0     45228.0
# 12      L      0      1          Arsenal  0.5  0.4  51.0     60233.0
# 13      W      2      1         Brighton  0.8  0.8  55.0     53466.0
# 14      W      3      1    ch Young Boys  4.2  0.4  69.0     31500.0
# 15      W      3      0   Manchester Utd  4.0  0.9  60.0     73502.0
# 16      W      6      1      Bournemouth  1.9  0.9  65.0     53358.0
# 17      W      3      0    ch Young Boys  3.3  0.0  72.0         NaN
# 18    NaN    NaN    NaN          Chelsea  NaN  NaN   NaN         NaN
# 19    NaN    NaN    NaN        Liverpool  NaN  NaN   NaN         NaN
# 20    NaN    NaN    NaN    de RB Leipzig  NaN  NaN   NaN         NaN
# 21    NaN    NaN    NaN        Tottenham  NaN  NaN   NaN         NaN
# 22    NaN    NaN    NaN      Aston Villa  NaN  NaN   NaN         NaN
# 23    NaN    NaN    NaN       Luton Town  NaN  NaN   NaN         NaN
# 24    NaN    NaN    NaN      rs Red Star  NaN  NaN   NaN         NaN
# 25    NaN    NaN    NaN   Crystal Palace  NaN  NaN   NaN         NaN
# 26    NaN    NaN    NaN        Brentford  NaN  NaN   NaN         NaN
# 27    NaN    NaN    NaN          Everton  NaN  NaN   NaN         NaN
# 28    NaN    NaN    NaN    Sheffield Utd  NaN  NaN   NaN         NaN
# 29    NaN    NaN    NaN    Newcastle Utd  NaN  NaN   NaN         NaN
# 30    NaN    NaN    NaN          Burnley  NaN  NaN   NaN         NaN
# 31    NaN    NaN    NaN        Brentford  NaN  NaN   NaN         NaN
# 32    NaN    NaN    NaN          Everton  NaN  NaN   NaN         NaN
# 33    NaN    NaN    NaN          Chelsea  NaN  NaN   NaN         NaN
# 34    NaN    NaN    NaN      Bournemouth  NaN  NaN   NaN         NaN
# 35    NaN    NaN    NaN   Manchester Utd  NaN  NaN   NaN         NaN
# 36    NaN    NaN    NaN        Liverpool  NaN  NaN   NaN         NaN
# 37    NaN    NaN    NaN         Brighton  NaN  NaN   NaN         NaN
# 38    NaN    NaN    NaN          Arsenal  NaN  NaN   NaN         NaN
# 39    NaN    NaN    NaN      Aston Villa  NaN  NaN   NaN         NaN
# 40    NaN    NaN    NaN   Crystal Palace  NaN  NaN   NaN         NaN
# 41    NaN    NaN    NaN       Luton Town  NaN  NaN   NaN         NaN
# 42    NaN    NaN    NaN        Tottenham  NaN  NaN   NaN         NaN
# 43    NaN    NaN    NaN  Nott'ham Forest  NaN  NaN   NaN         NaN
# 44    NaN    NaN    NaN           Wolves  NaN  NaN   NaN         NaN
# 45    NaN    NaN    NaN           Fulham  NaN  NaN   NaN         NaN
# 46    NaN    NaN    NaN         West Ham  NaN  NaN   NaN         NaN
#
#             Captain Formation            Referee  Match Report  \
# 0       Kyle Walker   4-2-3-1     Stuart Attwell  Match Report
# 1   Kevin De Bruyne   4-2-3-1       Craig Pawson  Match Report
# 2       Kyle Walker   4-2-3-1  François Letexier  Match Report
# 3       Kyle Walker   4-2-3-1       Robert Jones  Match Report
# 4       Kyle Walker   4-2-3-1     Jarred Gillett  Match Report
# 5       Kyle Walker   4-2-3-1     Michael Oliver  Match Report
# 6       Kyle Walker   4-2-3-1        Andy Madley  Match Report
# 7       Kyle Walker   4-2-3-1      João Pinheiro  Match Report
# 8       Kyle Walker   4-2-3-1     Anthony Taylor  Match Report
# 9        Nathan Aké   3-2-4-1     Chris Kavanagh  Match Report
# 10      Kyle Walker   4-2-3-1       Craig Pawson  Match Report
# 11      Kyle Walker   3-2-4-1  Artur Soares Dias  Match Report
# 12      Kyle Walker     4-3-3     Michael Oliver  Match Report
# 13      Kyle Walker   3-2-4-1       Robert Jones  Match Report
# 14       Rúben Dias   3-2-4-1       Morten Krogh  Match Report
# 15      Kyle Walker   4-2-3-1       Paul Tierney  Match Report
# 16      Kyle Walker     3-4-3       Craig Pawson  Match Report
# 17      Kyle Walker   3-2-4-1    Erik Lambrechts  Match Report
# 18              NaN       NaN                NaN  Head-to-Head
# 19              NaN       NaN                NaN  Head-to-Head
# 20              NaN       NaN                NaN  Head-to-Head
# 21              NaN       NaN                NaN  Head-to-Head
# 22              NaN       NaN                NaN  Head-to-Head
# 23              NaN       NaN                NaN  Head-to-Head
# 24              NaN       NaN                NaN  Head-to-Head
# 25              NaN       NaN                NaN  Head-to-Head
# 26              NaN       NaN                NaN           NaN
# 27              NaN       NaN                NaN  Head-to-Head
# 28              NaN       NaN                NaN  Head-to-Head
# 29              NaN       NaN                NaN  Head-to-Head
# 30              NaN       NaN                NaN  Head-to-Head
# 31              NaN       NaN                NaN  Head-to-Head
# 32              NaN       NaN                NaN  Head-to-Head
# 33              NaN       NaN                NaN  Head-to-Head
# 34              NaN       NaN                NaN  Head-to-Head
# 35              NaN       NaN                NaN  Head-to-Head
# 36              NaN       NaN                NaN  Head-to-Head
# 37              NaN       NaN                NaN  Head-to-Head
# 38              NaN       NaN                NaN  Head-to-Head
# 39              NaN       NaN                NaN  Head-to-Head
# 40              NaN       NaN                NaN  Head-to-Head
# 41              NaN       NaN                NaN  Head-to-Head
# 42              NaN       NaN                NaN  Head-to-Head
# 43              NaN       NaN                NaN  Head-to-Head
# 44              NaN       NaN                NaN  Head-to-Head
# 45              NaN       NaN                NaN  Head-to-Head
# 46              NaN       NaN                NaN  Head-to-Head
#
#                                                 Notes
# 0   Arsenal won on penalty kicks following normal ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                    Match Postponed
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links=[l.get('href') for l in links]
links= [l for l in links if l and 'c9/shooting' in l]

# %%
links
# Out:
# ['/en/squads/b8fd03ef/2023-2024/matchlogs/c9/shooting/Manchester-City-Match-Logs-Premier-League',
#  '/en/squads/b8fd03ef/2023-2024/matchlogs/c9/shooting/Manchester-City-Match-Logs-Premier-League',
#  '/en/squads/b8fd03ef/2023-2024/matchlogs/c9/shooting/Manchester-City-Match-Logs-Premier-League']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match='Shooting')[0]

# %%
shooting.head()
# Out:
#   For Manchester City                                              \
#                  Date   Time        Round  Day Venue Result GF GA
# 0          2023-08-11  20:00  Matchweek 1  Fri  Away      W  3  0
# 1          2023-08-19  20:00  Matchweek 2  Sat  Home      W  1  0
# 2          2023-08-27  14:00  Matchweek 3  Sun  Away      W  2  1
# 3          2023-09-02  15:00  Matchweek 4  Sat  Home      W  5  1
# 4          2023-09-16  15:00  Matchweek 5  Sat  Away      W  3  1
#
#                  Standard  ...                   Expected                    \
#         Opponent      Gls  ...  Dist FK PK PKatt       xG npxG npxG/Sh G-xG
# 0        Burnley        3  ...  13.9  0  0     0      1.9  1.9    0.12  1.1
# 1  Newcastle Utd        1  ...  17.9  0  0     0      1.0  1.0    0.07  0.0
# 2  Sheffield Utd        2  ...  17.3  2  0     1      3.5  2.8    0.10 -1.5
# 3         Fulham        5  ...  14.8  0  1     1      2.2  1.4    0.25  2.8
# 4       West Ham        3  ...  16.4  1  0     0      3.6  3.6    0.13 -0.6
#
#           Unnamed: 24_level_0
#   np:G-xG        Match Report
# 0     1.1        Match Report
# 1     0.0        Match Report
# 2    -0.8        Match Report
# 3     2.6        Match Report
# 4    -0.6        Match Report
#
# [5 rows x 25 columns]

# %%
shooting.columns= shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time        Round  Day Venue Result  GF  GA       Opponent  \
# 0  2023-08-11  20:00  Matchweek 1  Fri  Away      W   3   0        Burnley
# 1  2023-08-19  20:00  Matchweek 2  Sat  Home      W   1   0  Newcastle Utd
# 2  2023-08-27  14:00  Matchweek 3  Sun  Away      W   2   1  Sheffield Utd
# 3  2023-09-02  15:00  Matchweek 4  Sat  Home      W   5   1         Fulham
# 4  2023-09-16  15:00  Matchweek 5  Sat  Away      W   3   1       West Ham
#
#    Gls  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  \
# 0    3  ...  13.9   0   0      0  1.9   1.9     0.12   1.1      1.1
# 1    1  ...  17.9   0   0      0  1.0   1.0     0.07   0.0      0.0
# 2    2  ...  17.3   2   0      1  3.5   2.8     0.10  -1.5     -0.8
# 3    5  ...  14.8   0   1      1  2.2   1.4     0.25   2.8      2.6
# 4    3  ...  16.4   1   0      0  3.6   3.6     0.13  -0.6     -0.6
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3  Match Report
# 4  Match Report
#
# [5 rows x 25 columns]

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data
# Out:
#           Date   Time            Comp         Round  Day Venue Result GF GA  \
# 0   2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3  0
# 1   2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1  0
# 2   2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2  1
# 3   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5  1
# 4   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3  1
# 5   2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2  0
# 6   2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1  2
# 7   2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0  1
# 8   2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2  1
# 9   2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3  0
# 10  2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6  1
#
#            Opponent  ...  Formation         Referee  Match Report  Notes  Sh  \
# 0           Burnley  ...    4-2-3-1    Craig Pawson  Match Report    NaN  17
# 1     Newcastle Utd  ...    4-2-3-1    Robert Jones  Match Report    NaN  14
# 2     Sheffield Utd  ...    4-2-3-1  Jarred Gillett  Match Report    NaN  29
# 3            Fulham  ...    4-2-3-1  Michael Oliver  Match Report    NaN   6
# 4          West Ham  ...    4-2-3-1     Andy Madley  Match Report    NaN  29
# 5   Nott'ham Forest  ...    4-2-3-1  Anthony Taylor  Match Report    NaN   7
# 6            Wolves  ...    4-2-3-1    Craig Pawson  Match Report    NaN  23
# 7           Arsenal  ...      4-3-3  Michael Oliver  Match Report    NaN   4
# 8          Brighton  ...    3-2-4-1    Robert Jones  Match Report    NaN  10
# 9    Manchester Utd  ...    4-2-3-1    Paul Tierney  Match Report    NaN  20
# 10      Bournemouth  ...      3-4-3    Craig Pawson  Match Report    NaN  21
#
#    SoT  Dist FK PK  PKatt
# 0    8  13.9  0  0      0
# 1    4  17.9  0  0      0
# 2    9  17.3  2  0      1
# 3    4  14.8  0  1      1
# 4   13  16.4  1  0      0
# 5    4  17.2  2  0      0
# 6    8  19.3  1  0      0
# 7    0  14.9  0  0      0
# 8    5  18.8  1  0      0
# 9    9  17.2  2  1      1
# 10   8  16.4  0  0      0
#
# [11 rows x 25 columns]

# %%
 years = list(range(2023, 2019, -1))
all_matches = []

# %% [markdown]
# # Main code

# %%
years
# Out:
# [2023, 2022, 2021, 2020]

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
# !pip install html5lib
# !pip install lxml
# !pip install beautifulSoup4
import html5lib
import lxml
from bs4 import BeautifulSoup
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'c9/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(5)
# Out:
# Requirement already satisfied: html5lib in c:\users\user\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\user\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: beautifulSoup4 in c:\users\user\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulSoup4) (2.3.1)

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp         round  day venue result gf ga  \
# 0   2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3  0
# 1   2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1  0
# 2   2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2  1
# 3   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5  1
# 4   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3  1
# ..         ...    ...             ...           ...  ...   ...    ... .. ..
# 33  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0  4
# 34  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0  2
# 35  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1  0
# 36  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0  1
# 37  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1  0
#
#           opponent  ...  match report  notes  sh  sot  dist fk pk pkatt  \
# 0          Burnley  ...  Match Report    NaN  17    8  13.9  0  0     0
# 1    Newcastle Utd  ...  Match Report    NaN  14    4  17.9  0  0     0
# 2    Sheffield Utd  ...  Match Report    NaN  29    9  17.3  2  0     1
# 3           Fulham  ...  Match Report    NaN   6    4  14.8  0  1     1
# 4         West Ham  ...  Match Report    NaN  29   13  16.4  1  0     0
# ..             ...  ...           ...    ...  ..  ...   ... .. ..   ...
# 33       Tottenham  ...  Match Report    NaN   8    1  18.2  0  0     0
# 34  Crystal Palace  ...  Match Report    NaN   7    0  13.4  1  0     0
# 35         Everton  ...  Match Report    NaN  10    3  18.5  0  0     0
# 36   Newcastle Utd  ...  Match Report    NaN  11    1  18.3  1  0     0
# 37         Burnley  ...  Match Report    NaN  12    3  17.4  0  0     0
#
#    season              team
# 0    2023   Manchester City
# 1    2023   Manchester City
# 2    2023   Manchester City
# 3    2023   Manchester City
# 4    2023   Manchester City
# ..    ...               ...
# 33   2020  Sheffield United
# 34   2020  Sheffield United
# 35   2020  Sheffield United
# 36   2020  Sheffield United
# 37   2020  Sheffield United
#
# [2500 rows x 27 columns]

# %%
match_df.to_csv("matches.csv")

# %%
matches.dtypes
# Out:
# Date             object
# Time             object
# Comp             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF               object
# GA               object
# Opponent         object
# xG              float64
# xGA             float64
# Poss              int64
# Attendance      float64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Notes            object
# dtype: object
